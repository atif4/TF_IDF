# %%
# EDA pamages 
import pandas as pd

#hide wearrings 
import warnings

warnings.filterwarnings('ignore')
#import the necessary module

from sklearn import preprocessing
# create the Labelencoder object
le = preprocessing.LabelEncoder()
#convert the categorical columns into numeric
le = preprocessing.LabelEncoder()

from sklearn.model_selection import train_test_split
#split data set into train and test sets

# import the necessary module
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
#create an object of the type GaussianNB
gnb = GaussianNB()

#import necessary modules
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
class Dataset_tf():
    """A simple attempt to model a dog."""
    def __init__(self, df):
        """Initialize name and age attributes."""
        self.df = pd.read_csv(df)
    def get_convert_dtype(list_of_c_ids):
        for list_of_c_id in list_of_c_ids:
            df[list_of_c_id] = df[list_of_c_id].apply(pd.to_numeric)
            # convert just columns "a" and "b" df[["a", "b"]] = df[["a", "b"]].apply(pd.to_numeric)
            df[list_of_c_id] = df[list_of_c_id].astype(int)
    def get_LabelEncoder(self,labelencoders_list):
        for labelencoder_list in labelencoders_list:
            self.df[labelencoder_list] = le.fit_transform(self.df[labelencoder_list])
            #return self.df[labelencoder_list]
    def get_divided_df(self,c_id1,c_id2):
        # select columns other than 'Opportunity Number','Opportunity Result'
        cols = [col for col in self.df.columns if col not in [c_id1,c_id2]]
        global data , target
        # dropping the 'Opportunity Number'and 'Opportunity Result' columns
        data = self.df[cols]
        #assigning the Oppurtunity Result column as target
        target = self.df[c_id1]
        return data
    def get_test_train(self):
        data_train, data_test, target_train, target_test = train_test_split(data  , target , test_size = 0.30, random_state = 10)
        return data_train, data_test, target_train, target_test
    def get_prediction(self):
        #train the algorithm on training data and predict using the testing data
        pred = gnb.fit(data_train, target_train).predict(data_test)
        print('Prediction',pred.tolist())
        print ('the accuracy score of the model')
        print("Naive-Bayes accuracy : ",accuracy_score(target_test, pred, normalize = True))
    def get_lassifier(self):
        #create object of the lassifier
        neigh = KNeighborsClassifier(n_neighbors=3)
        #Train the algorithm
        neigh.fit(data_train, target_train)
        # predict the response
        pred = neigh.predict(data_test)
        # evaluate accuracy
        print ("KNeighbors accuracy score : ",accuracy_score(target_test, pred))

# %%
my_dataset_tf = Dataset_tf("C:\\Users\\haier\\Python\\TEXT_DATA_PREPROCESSING\\Data_sets\\subset_covid19_tweets.csv")

# %%
my_dataset_tf.df.index.name='S:No' ; my_dataset_tf.df.columns.name = 'Info'

# %%
my_dataset_tf.df.drop("Unnamed: 0",axis=1,inplace=True)

# %%
my_dataset_tf.df.reindex(range(1,265))
# Out:
# Info           user_name         user_location  \
# S:No
# 1          Tom Basile 🇺🇸          New York, NY
# 2        Time4fisticuffs      Pewee Valley, KY
# 3            ethel mertz  Stuck in the Middle
# 4               DIPR-J&K     Jammu and Kashmir
# 5       🎹 Franz Schubert           Новоро́ссия
# ...                  ...                   ...
# 260   Ryan T. Cleary, MD          St Louis, MO
# 261        Dara Kass, MD          New York, NY
# 262   Samantha Sovereign        Massachusetts
# 263    APO Group English         #AFRICA #MENA
# 264    HAMSEY Enterprise        Lagos, Nigeria
#
# Info                                   user_description         user_created  \
# S:No
# 1     Husband, Father, Columnist & Commentator. Auth...  2009-04-16 20:06:23
# 2     #Christian #Catholic #Conservative #Reagan #Re...  2009-02-28 18:57:41
# 3     #Browns #Indians #ClevelandProud #[]_[] #Cavs ...  2019-03-07 01:45:06
# ...

# %%
my_dataset_tf.df.dropna(inplace=True)

# %%
my_dataset_tf.df.columns
# Out:
# Index(['user_name', 'user_location', 'user_description', 'user_created',
#        'user_followers', 'user_friends', 'user_favourites', 'user_verified',
#        'date', 'text', 'hashtags', 'source', 'is_retweet'],
#       dtype='object', name='Info')

# %%
my_dataset_tf.get_LabelEncoder(['user_name', 'user_location', 'user_description', 'user_created',
       'user_followers', 'user_friends', 'user_favourites', 'user_verified',
       'date', 'text', 'hashtags', 'source', 'is_retweet'])

# %%
my_dataset_tf.df
# Out:
# Info  user_name  user_location  user_description  user_created  \
# S:No
# 2           209            137                 3            17
# 3           240            159                 2           217
# 4            46             89               251           189
# 5           253            198               249           202
# 6           242             64               231             4
# ...         ...            ...               ...           ...
# 487         245            107               104            91
# 488          54             41                85           125
# 490         121            175                 5           227
# 491         104             16               238           219
# 499          76            182                42            75
#
# Info  user_followers  user_friends  user_favourites  user_verified  date  \
# S:No
# 2                176           224              156              0   238
# ...

# %%
my_dataset_tf.get_divided_df('user_name','text')
# Out:
# Info  user_location  user_description  user_created  user_followers  \
# S:No
# 2               137                 3            17             176
# 3               159                 2           217              44
# 4                89               251           189             227
# 5               198               249           202             113
# 6                64               231             4             224
# ...             ...               ...           ...             ...
# 487             107               104            91             179
# 488              41                85           125             167
# 490             175                 5           227              25
# 491              16               238           219              73
# 499             182                42            75             207
#
# Info  user_friends  user_favourites  user_verified  date  hashtags  source  \
# S:No
# ...

# %%
data_train, data_test, target_train, target_test  = my_dataset_tf.get_test_train()

# %%
data_test
# Out:
# Info  user_location  user_description  user_created  user_followers  \
# S:No
# 229             173                 8           139             187
# 136              93                54            51             216
# 104             146                76           111             172
# 428             182                42            75             207
# 198              33                16           107             156
# ...             ...               ...           ...             ...
# 9               199               128           167             218
# 284              27                68            28              61
# 153             187               234           131             142
# 358             108               124           186              52
# 430              91               146           239              27
#
# Info  user_friends  user_favourites  user_verified  date  hashtags  source  \
# S:No
# ...

# %%
data_train
# Out:
# Info  user_location  user_description  user_created  user_followers  \
# S:No
# 4                89               251           189             227
# 400              67                24           169             196
# 437               0                98           147              63
# 408              20                35           224             108
# 137              71                32            61              19
# ...             ...               ...           ...             ...
# 288              96                40           245              49
# 235              15                 7           142             243
# 27              110               212             1              23
# 237             113                99            13             131
# 491              16               238           219              73
#
# Info  user_friends  user_favourites  user_verified  date  hashtags  source  \
# S:No
# ...

# %%
target_test
# Out:
# S:No
# 229    216
# 136     95
# 104    235
# 428     76
# 198    165
#       ...
# 9      129
# 284    130
# 153    233
# 358    145
# 430      3
# Name: user_name, Length: 81, dtype: int32

# %%
target_train
# Out:
# S:No
# 4       46
# 400    202
# 437    142
# 408    105
# 137    185
#       ...
# 288     66
# 235     29
# 27     236
# 237    118
# 491    104
# Name: user_name, Length: 186, dtype: int32

# %%
my_dataset_tf.get_prediction()
# Out:
# Prediction [47, 22, 169, 56, 57, 180, 109, 102, 36, 133, 41, 157, 58, 122, 167, 169, 215, 248, 67, 133, 119, 74, 169, 56, 160, 99, 7, 67, 196, 237, 168, 43, 131, 79, 167, 67, 150, 245, 204, 148, 61, 143, 184, 150, 81, 43, 123, 10, 226, 21, 185, 70, 58, 217, 40, 196, 245, 7, 168, 150, 127, 171, 189, 55, 239, 225, 184, 226, 253, 183, 245, 231, 215, 60, 250, 57, 140, 124, 159, 192, 63]
# the accuracy score of the model
# Naive-Bayes accuracy :  0.04938271604938271

# %%
my_dataset_tf.get_lassifier()
# Out:
# KNeighbors accuracy score :  0.012345679012345678
